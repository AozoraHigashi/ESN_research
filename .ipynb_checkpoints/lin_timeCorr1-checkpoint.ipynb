# %%
import torch
import matplotlib.pyplot as plt
import ESN
import time
import numpy as np
torch.set_default_device("cuda:0")
torch.set_default_dtype(torch.double)
# Parameters
Two,Ttrain = 2000,10000
N = 100
C = 0.9
rho = 0
dim = 1
idWin = False


N_d = int(N * dim)
maxtau = int(N_d * 2)
taus = np.arange(1,maxtau)



torch.manual_seed(0)



#u_asym = torch.rand(1, Two + Ttrain)

x = torch.normal(0,1,(1,Two+Ttrain),device="cuda:0")
print(x.shape)
print(x)

u_sym = torch.tensor([[ torch.sum(x[:,:t+1],1) for t in range(Two+Ttrain)]])
u_tilde = x
print(u_sym[:30])
print()

exit()

esn = ESN.ESN_mult(N_d, uC=C, dim=dim,rseed=0,idWin=idWin)



st = time.time()
Xwo = esn.run_washout(u_sym, Two, actf="identity",bias=False)
print("runtime :",time.time()-st)

st = time.time()
#
raw,lin,rev,sur = ESN.MC_cSVD_asym(u_sym, Xwo, maxtau,ret_all=True)
raw_tilde,lin_tilde,rev_tilde,sur_tilde = ESN.MC_cSVD_asym(u_tilde, Xwo, maxtau,ret_all=True)


mfs=rev
print("calc time :",time.time()-st)


totMC = torch.sum(mfs).cpu().numpy()

print(f"totMC:{totMC}\nsurrogate value: {sur.cpu().numpy()}")
# Out:
# torch.Size([1, 12000])
# tensor([[-0.3104, -0.0343,  0.1756,  ...,  0.5688,  0.9929,  0.9880]],
#        device='cuda:0')
# tensor([-0.3104, -0.3447, -0.1691, -2.4495, -1.9457, -1.3860, -1.4610, -0.4919,
#         -0.7276, -1.1858, -0.6197,  0.6654, -1.2013, -1.2325,  0.0108,  1.3797,
#          0.3044,  0.2886, -1.1595, -2.4684, -1.7704, -2.1004, -2.8712, -3.3658,
#         -0.1956, -0.1569, -1.7296, -0.4311, -0.8730, -1.5695], device='cuda:0')
# Input dimension error: input must be shape (1, T)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 43
#      38 esn = ESN.ESN_mult(N_d, uC=C, dim=dim,rseed=0,idWin=idWin)
#      42 st = time.time()
# ---> 43 Xwo = esn.run_washout(u_sym, Two, actf="identity",bias=False)
#      44 print("runtime :",time.time()-st)
#      46 st = time.time()
#
# File ~/NASshare/Higashi/ESN_research/ESN.py:44, in ESN_mult.run_washout(self, u, Two, actf, f, X0, bias)
#      41 if u.shape[0] != self.dim:
#      42     print(f"Input dimension error: input must be shape ({self.dim}, T)")
# ---> 44 T = u.shape[1]
#      45 X = torch.zeros((T, self.N))
#      46 X[0] = X0
#
# IndexError: tuple index out of range

# %%
runtime : 1.4590129852294922
torch.Size([101])
tensor(14.1067, device='cuda:0')
calc time : 0.2050008773803711
totMC:99.99737850069407
surrogate value: [0.01002908]

# %%
fig,ax = plt.subplots(figsize=(12,8))
mfs = rev
for d in range(dim):
    plt.plot(taus,mfs[d].cpu().numpy(),alpha=0.6,label="dim "+str(d))
plt.ylim(-0.1,1.1)
plt.xlabel("delay")
plt.ylabel(r'Memory function $MC^{(k)}(\tau)$')
plt.title(r'Ttr = %d, C=%.2f,$N=%d, totalMC=%.1f$'%(Ttrain,C,N_d,totMC))
#
plt.legend()
plt.grid(True)

# %%
fig,ax = plt.subplots(figsize=(12,8))
mfs = rev
for d in range(dim):
    plt.plot(taus,mfs[d].cpu().numpy(),alpha=0.6,label="dim "+str(d))
plt.ylim(-0.1,1.1)
plt.xlabel("delay")
plt.ylabel(r'Memory function $MC^{(k)}(\tau)$')
plt.title(r'Ttr = %d, C=%.2f,$N=%d, totalMC=%.1f$'%(Ttrain,C,N_d,totMC))
#
plt.legend()
plt.grid(True)
